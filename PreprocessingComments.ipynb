# %%
import pandas as pd
import seaborn as sns
import numpy as np
from googleapiclient.discovery import build

# %%
# !pip install langdetect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=56217a3eb4e8ac8f55b3bb47ac1ec28c3d3a9dd6e36628b5cba18fecb0f9a1cd
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from langdetect import detect
import spacy
import re

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df1= pd.read_csv("/content/drive/MyDrive/ndtv Demonetisation.csv")

# %%
df1.dropna()
# Out:
#                                           comment_text  comment_replies  \
# 0            R.Rajan is a genius among most economists                0
# 1    Why is Raghuram Rajan not the Prime Minister o...                5
# 2                    "Demonetisation was the bad idea"                0
# 3                    Sir plz upload the full interview                0
# 4                          Sach bol diye....kahe??????                0
# ..                                                 ...              ...
# 286  sir we want to zyka india Ka again by Vinod du...                1
# 287  please Cover the Commual riots happening in  W...                0
# 288                             Why every one 🇮🇳 India                1
# 289  kisi ke paas black money hai mujhe de do 80% 6...                7
# 290  sir we want to zyka india Ka again by Vinod du...                1
#
#     comment_date comment_relative_date
# 0    ~2019-02-06           5 years ago
# ...

# %%
df1.head()
# Out:
#                                         comment_text  comment_replies  \
# 0          R.Rajan is a genius among most economists                0
# 1  Why is Raghuram Rajan not the Prime Minister o...                5
# 2                  "Demonetisation was the bad idea"                0
# 3                  Sir plz upload the full interview                0
# 4                        Sach bol diye....kahe??????                0
#
#   comment_date comment_relative_date
# 0  ~2019-02-06           5 years ago
# 1  ~2020-02-06           4 years ago
# 2  ~2019-02-06           5 years ago
# 3  ~2019-02-06           5 years ago
# 4  ~2019-02-06           5 years ago

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=291, step=1)

# %%
Comments=[]

for comment in df1["comment_text"]:
  if(len(comment)==0):
   Comments.append("")
   # print(comment)
   df1.drop(comment)

  #print(detect(comment))
  #if(detect(comment)=='en'):
    #Comments.append(comment)
  try:
    if(detect(comment)=='en'):
      Comments.append(comment)
    else:
      Comments.append("")
  except Exception as e:
    print(comment)
    #df1.drop(index=str(comment), inplace=True)
    #print(df1['comment_text'].loc[comment])
    #print(df1.get_loc(comment))
    #print(df1['comment_text'].index(comment))
    Comments.append("")
    #print("Error during language detection:", e)
len(Comments)
# Out:
# ♥
# 🌹
# 🥀
# 2021
# 2019
# 🙏  🙏
# 291

# %%
nlp = spacy.load('en_core_web_sm')
def clean(text):
  doc=nlp(text)
  noPuncText=""
  for token in doc:
    if not token.is_punct :
      noPuncText=noPuncText+" "+token.text
  lowerText=""
  for word in noPuncText:
    lowerText=lowerText+word.lower()
  #stop word remove
  doc = nlp(lowerText)

  filtered_words = [token.text for token in doc if not token.is_stop]

  new_string = ' '.join(filtered_words)
  # eeeemoji
  emoj = re.compile("["
        u"\U00002700-\U000027BF"  # Dingbats
        u"\U0001F600-\U0001F64F"  # Emoticons
        u"\U00002600-\U000026FF"  # Miscellaneous Symbols
        u"\U0001F300-\U0001F5FF"  # Miscellaneous Symbols And Pictographs
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U0001F680-\U0001F6FF"  # Transport and Map Symbols
                      "]+", re.UNICODE)
  return re.sub(emoj, '', new_string)


clean("Hi this is Arya !🤓")
# Out:
# '  hi arya '

# %%
CleanComments=[]
for comment in Comments:
  CleanComments.append(clean(comment))
print(len(CleanComments))

df1['Clean Comments']=CleanComments
# Out:
# 291

# %%
df1=df1.drop(['comment_replies'],axis=1)
df1=df1.drop(['comment_relative_date'],axis=1)
df1['comment_date']=df1['comment_date'].str.replace('~','')

# %%
#df1['comment_date'] = df1['comment_date'].astype(str)
#df1['comment_date']=pd.to_datetime(df1['comment_date'])
df1=df1.drop(['comment_text'],axis=1)
print(type(df1['comment_date']))
df1
# Out:
# <class 'pandas.core.series.Series'>
#     comment_date                                     Clean Comments
# 0     2019-02-06                          r.rajan genius economists
# 1     2020-02-06    raghuram rajan prime minister india uneducat...
# 2     2019-02-06                            demonetisation bad idea
# 3     2019-02-06                           sir plz upload interview
# 4     2019-02-06
# ..           ...                                                ...
# 286   2017-02-06
# 287   2017-02-06       cover commual riots happening    west bengal
# 288   2017-02-06                                          🇮 🇳 india
# 289   2017-02-06
# 290   2017-02-06               sir want zyka india ka vinod dua sir
#
# [291 rows x 2 columns]

# %%
df1.to_excel('ndtv preprocessed.xlsx',index=False)

# %% [markdown]
# ### Preprocessing Functions do not use

# %%
def remove_punctuation(text):
  doc=nlp(text)
  noPuncText=""
  for token in doc:
    if not token.is_punct :
      noPuncText=noPuncText+" "+token.text
  return noPuncText
def lowercase(text):
  lowerText=""
  for word in text:
    lowerText=lowerText+word.lower()
  #mainText=lowerText
  return mainText
def remove_emojis(data):
    emoj = re.compile("["
        u"\U00002700-\U000027BF"  # Dingbats
        u"\U0001F600-\U0001F64F"  # Emoticons
        u"\U00002600-\U000026FF"  # Miscellaneous Symbols
        u"\U0001F300-\U0001F5FF"  # Miscellaneous Symbols And Pictographs
        u"\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        u"\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        u"\U0001F680-\U0001F6FF"  # Transport and Map Symbols
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
def remove_stop_words(string):
    # Load the spaCy English language model
    nlp = spacy.load('en_core_web_sm')

    # Tokenize the string into individual words
    doc = nlp(string)

    # Filter out stop words
    filtered_words = [token.text for token in doc if not token.is_stop]

    # Join the filtered words back into a string
    new_string = ' '.join(filtered_words)

    return new_string
mainText=remove_stop_words(mainText)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3f4b02d70dae> in <cell line: 39>()
#      37
#      38     return new_string
# ---> 39 mainText=remove_stop_words(mainText)
#
# NameError: name 'mainText' is not defined
